# %% [markdown]
# # Convert shapely geometry to bokeh feature
#
# From ShapelyAddons Class :
# ==> geometry_2_bokeh_format

# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

from bokeh.plotting import output_notebook
from bokeh.plotting import show
from bokeh.io import curdoc, show

from shapely.wkt import loads as wkt_loads
from main_funcs import ExamplesCore
from main_funcs import BokehCore

output_notebook()

a_point = wkt_loads('Point (0 0 5)')
a_linestring = wkt_loads('LineString (0 0 0, 2 0 0)')
a_multilinestring = wkt_loads(
    'MULTILINESTRING Z ('
    '(0 0 0, 0 -5 0),'
    '(-1 2 0, 0 -5 0)'
    ')'
)
a_polygon = wkt_loads('Polygon ((10 10 1, 110 10 2, 110 110 1, 10 110 1, 10 10 1))')
a_polygon_with_holes = wkt_loads('Polygon ((20 130 1, 120 130 2, 120 230 6, 20 230 5, 20 130 1),(30 140 5, 30 150 5, 40 150 5, 40 140 5, 30 140 5),(50 140 5, 50 150 5, 60 150 5, 60 140 5, 50 140 5))')
a_multipolygon_with_holes = wkt_loads('MultiPolygon (((138 134 1, 238 134 2, 238 234 6, 138 234 5, 138 134 1),(148 144 5, 148 154 5, 158 154 5, 158 144 5, 148 144 5),(168 144 5, 168 154 5, 178 154 5, 178 144 5, 168 144 5)))')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1035">Loading BokehJS ...</span>
#     </div>

# %%
figure = BokehCore()

figure.add_points([a_point], 'a_Point', 'blue', size=10)

figure.add_lines([a_linestring], 'a_LineString', 'red')
figure.add_multi_lines(a_multilinestring, 'a_MultiLineString', 'brown')

figure.add_polygons(a_polygon_with_holes, 'a_polygon_with_holes', 'green')
figure.add_polygons(a_multipolygon_with_holes, 'a_multipolygon_with_holes', 'teal')



show(figure._plot)
# Out:
#   <div class="bk-root" id="46154755-11bf-410f-8d7f-e231013e0d09" data-root-id="1001"></div>
